# %% [markdown]
# # Import a dataset and do a first qick inspection on it

# %%
import pandas as pd

# %% [markdown]
# ### Download dataset

# %%
import requests

def download_data(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

# %% [markdown]
# ### Read data into dataframe

# %%
url = 'https://storage.googleapis.com/kagglesdsdata/datasets/4991991/8392037/airlines.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240514%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240514T155239Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...'
filename = 'airlines.csv'
download_data(url, filename)
df = pd.read_csv(filename)
df
# Out:
#       Airline ID                                          Name  \
# 0             -1                                       Unknown
# 1              1                                Private flight
# 2              2                                   135 Airways
# 3              3                                 1Time Airline
# 4              4  2 Sqn No 1 Elementary Flying Training School
# ...          ...                                           ...
# 6157       21248                                   GX Airlines
# 6158       21251                        Lynx Aviation (L3/SSX)
# 6159       21268                               Jetgo Australia
# 6160       21270                                  Air Carnival
# 6161       21317                                 Svyaz Rossiya
#
#                   Alias IATA ICAO         Callsign         Country Active
# 0                    \N    -  NaN               \N              \N      Y
# ...

# %% [markdown]
# ### Get first 5 rows

# %%
df.head(5)
# Out:
#    Airline ID                                          Name Alias IATA ICAO  \
# 0          -1                                       Unknown    \N    -  NaN
# 1           1                                Private flight    \N    -  NaN
# 2           2                                   135 Airways    \N  NaN  GNL
# 3           3                                 1Time Airline    \N   1T  RNX
# 4           4  2 Sqn No 1 Elementary Flying Training School    \N  NaN  WYT
#
#   Callsign         Country Active
# 0       \N              \N      Y
# 1      NaN             NaN      Y
# 2  GENERAL   United States      N
# 3  NEXTIME    South Africa      Y
# 4      NaN  United Kingdom      N

# %% [markdown]
# ### Get last 10 rows

# %%
df.tail(10)
# Out:
#       Airline ID                       Name                  Alias IATA ICAO  \
# 6152       21124                     ViaAir  Charter Air Transport  NaN  SRY
# 6153       21131           All America BOPY       All America BOPY   0P  PYB
# 6154       21179           Thai Vietjet Air                    NaN  NaN  TVJ
# 6155       21181           Air Andaman (2Y)                    NaN   2Y  AOW
# 6156       21240  TDA Toa Domestic Airlines                    TDA  NaN  TDA
# 6157       21248                GX Airlines                    NaN  NaN  CBG
# 6158       21251     Lynx Aviation (L3/SSX)                    NaN  NaN  SSX
# 6159       21268            Jetgo Australia                    NaN   JG   \N
# 6160       21270               Air Carnival                    NaN   2S   \N
# 6161       21317              Svyaz Rossiya      Russian Commuter    7R  SJM
#
#              Callsign        Country Active
# 6152         Stingray  United States      Y
# ...

# %% [markdown]
# ### Drop missing values of column Callsign

# %%
df = df.dropna(subset=['Callsign'],axis=0)
df.tail(10)
# Out:
#       Airline ID                                         Name  \
# 6142       20986  University of Birmingham Air Squadron (RAF)
# 6148       21021                                      Nordica
# 6152       21124                                       ViaAir
# 6153       21131                             All America BOPY
# 6154       21179                             Thai Vietjet Air
# 6155       21181                             Air Andaman (2Y)
# 6156       21240                    TDA Toa Domestic Airlines
# 6157       21248                                  GX Airlines
# 6158       21251                       Lynx Aviation (L3/SSX)
# 6161       21317                                Svyaz Rossiya
#
#                       Alias IATA ICAO         Callsign         Country Active
# 6142               8AEF RAF  NaN  UAY              UAY  United Kingdom      Y
# 6148                    NaN   EE   \N            REVAL         Estonia      Y
# ...

# %% [markdown]
# ### Column names of the dataframe

# %%
df.columns
# Out:
# Index(['Airline ID', 'Name', 'Alias', 'IATA', 'ICAO', 'Callsign', 'Country',
#        'Active'],
#       dtype='object')

# %% [markdown]
# ### Get data types of the dataframe

# %%
df.dtypes
# Out:
# Airline ID     int64
# Name          object
# Alias         object
# IATA          object
# ICAO          object
# Callsign      object
# Country       object
# Active        object
# dtype: object

# %% [markdown]
# ### Get the statistical summary

# %%
df.describe()
# Out:
#          Airline ID
# count   5354.000000
# mean    3451.908106
# std     3440.517779
# min       -1.000000
# 25%     1441.250000
# 50%     2904.500000
# 75%     4377.750000
# max    21317.000000

# %% [markdown]
# ### Get all info of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5354 entries, 0 to 6161
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Airline ID  5354 non-null   int64
#  1   Name        5354 non-null   object
#  2   Alias       5146 non-null   object
#  3   IATA        1141 non-null   object
#  4   ICAO        5349 non-null   object
#  5   Callsign    5354 non-null   object
#  6   Country     5350 non-null   object
#  7   Active      5354 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 376.5+ KB
